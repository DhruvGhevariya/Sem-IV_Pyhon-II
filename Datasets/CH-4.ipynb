# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("diabetes_unclean.csv")
print(data)
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# 2      0.5  24.0     N
# 3      0.5  24.0     N
# 4      0.4  21.0     N
# ...    ...   ...   ...
# 1004   0.9  30.1    Y
# 1005   1.8  30.0    Y
# 1006   NaN  30.1    Y
# 1007   1.3  29.0    Y
# 1008   0.7  33.0    Y
#
# [1009 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Gender"]=df["Gender"].replace('f',"F")

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    570
# F    439
# Name: count, dtype: int64

# %%
y=df[["CLASS"]]
y
# Out:
#      CLASS
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
# ...    ...
# 1004    Y
# 1005    Y
# 1006    Y
# 1007    Y
# 1008    Y
#
# [1009 rows x 1 columns]

# %%
x=df.drop(["ID","No_Pation","CLASS"],axis=1)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
print(x_train)
print(x_test)
# Out:
#     Gender   AGE  Urea    Cr  HbA1c  Chol    TG   HDL  LDL  VLDL    BMI
# 76       F  35.0  3.30  44.0    5.0   4.1  1.90  4.00  1.3   0.7  23.00
# 704      M  55.0  6.66  61.0    7.7   4.1  2.03  1.08  2.2  14.0  37.62
# 162      M  45.0  5.30  77.0   11.2   3.9  1.50  1.30  2.0  10.4  29.50
# 762      M  60.0  6.20  35.0    8.5   5.8  2.90  0.40  3.0   1.6  32.00
# 144      M  50.0  4.70  53.0    6.1   4.2  2.20  0.80  2.5   0.9  24.00
# ..     ...   ...   ...   ...    ...   ...   ...   ...  ...   ...    ...
# 738      F  55.0  4.70  34.0    9.9   5.1  4.50  0.60  2.7   2.0  31.00
# 211      F  33.0  1.80  31.0    7.4   3.7  1.20  1.60  1.5   0.5  31.50
# 305      M  55.0  3.70  93.0    7.2   3.2  1.90  0.60  1.8   0.8  30.00
# 361      F  55.0  2.30  36.0   10.2   4.8  1.00  1.40  2.9   0.4  36.60
# 72       F  41.0  2.00  39.0    4.0   3.4  1.20  1.70  1.1   0.5  21.00
#
# [807 rows x 11 columns]
#     Gender   AGE  Urea     Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 123      F  39.0   3.0   46.0    6.4   4.7  1.3  1.1  3.1   0.6  24.0
# 985      F  75.0  10.3  113.0    8.6   4.2  1.6  0.9  2.6   0.7  32.0
# 464      M  54.0   4.7   78.0    7.3   3.6  1.7  0.8  2.1   0.7  29.0
# 824      M  60.0   4.1   78.0   11.0   3.8  0.7  0.7  2.8   0.3  35.0
# 274      F  60.0   6.0   72.0   10.7   4.4  2.1  1.1  2.5   0.9  26.0
# ..     ...   ...   ...    ...    ...   ...  ...  ...  ...   ...   ...
# 342      M  58.0   4.8   60.0    5.5   0.6  2.5  1.1  2.0   0.6  38.0
# 436      F  56.0   1.9   20.0   11.7   5.5  5.3  0.9  1.3   1.2  33.0
# 884      M  51.0  38.9   58.0    6.8   5.9  2.6  1.4  3.4   1.2  33.0
# 897      F  61.0   8.1   72.0   16.0   7.7  3.1  1.6  4.9   1.4  26.0
# 916      F  44.0   4.6   54.0    9.4   6.8  2.9  1.1  4.5   1.3  23.0
#
# [202 rows x 11 columns]

# %%
print(y_train)
print(y_test)
# Out:
#     CLASS
# 76      N
# 704     Y
# 162     Y
# 762     Y
# 144     P
# ..    ...
# 738     Y
# 211     Y
# 305     Y
# 361     Y
# 72      N
#
# [807 rows x 1 columns]
#     CLASS
# 123     P
# 985     Y
# 464     Y
# 824     Y
# 274     Y
# ..    ...
# 342     Y
# 436     Y
# 884     Y
# 897     Y
# 916     Y
#
# [202 rows x 1 columns]
